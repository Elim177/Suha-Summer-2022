# %%
api_key = "AIzaSyAt4vOid3srxP0ht_qRswDam34Zp6QacWo"

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_videos(channel_id):
    
    # get Uploads playlist id
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
videos = get_channel_videos('UC0rqucBdTuFTjJiefW5t-IQ')

# %%
len(videos)
# Out:
# 526

# %%
for video in videos:
    print(video['snippet']['title'])
# Out:
# Top AI and ML announcements from Google I/O 2022
# Build a smart IoT device with TensorFlow Lite and Raspberry Pi
# Deploy a custom Machine Learning model to mobile
# TensorFlow.js: From prototype to production, what's new in 2022?
# An introduction to MLOps with TensorFlow Extended (TFX)
# Machine Learning for developers in a hurry
# Tips and tricks for distributed large model training
# A developer's guide to responsible AI review processes
# Easier data processing with Keras
# Introducing Coral Dev Board Micro
# Adding Machine Learning to your developer toolbox
# How to customize Machine Learning models the simple way
# AI and Machine Learning for developers
# Apply responsible AI principles when building remote sensing datasets
# Transfer learning in JavaScript with TensorFlow.js
# Product fairness testing for Machine Learning developers
# A journey to protect the Great Barrier Reef using Machine Learning
# Federated Reconstruction for Matrix Factorization (Building recommendation systems with TensorFlow)
# Building an on-device recommendation model with TFLite
# Item-to-item recommendation and sequential recommendation
# Building a listwise ranking model with TF Recommenders and TF Ranking
# Keras Preprocessing Layers
# Recommendation with TF Agents Bandits Library (Reinforcement learning with TensorFlow Agents)
# Introduction to TF Agents Bandits Library (Reinforcement learning with TensorFlow Agents)
# Continuous control and Actor-Learner API (Reinforcement learning with TensorFlow Agents)
# Build a board game app with policy gradient (Reinforcement learning with TensorFlow Agents)
# Introduction to TF Agents and Deep Q Learning (Reinforcement learning with TensorFlow Agents)
# Reinforcement learning overview (Reinforcement learning with TensorFlow Agents)
# MirroredStrategy demo for distributed training
# A friendly introduction to distributed training (ML Tech Talks)
# Make object detection faster by using Coral
# Choose an object detection model architecture for Raspberry Pi
# Train a custom object detection model using your data
# Google Colab features you may have missed
# Introduction to object detection on Raspberry Pi
# Help Protect the Great Barrier Reef with Machine Learning
# Incredible things your community is creating with TensorFlow.js  - #MadeWithTFJS
# How to get involved in Machine Learning
# Chip floorplanning with deep reinforcement learning
# Cloud TPU v4: Fast, flexible, and easy-to-use ML accelerators
# Simplified distributed training with tf.distribute parameter servers
# Building Machine Learning models with Edge Impulse
# Intro to JAX: Accelerating Machine Learning research
# Building fair, ethical, and responsible AI with the Responsible AI Toolkit
# Manage MLOps and deploy Machine Learning to production with the new and improved TFX
# Simplified Machine Learning on mobile, browsers, and edge devices with on-device ML
# State-of-the-art Machine Learning research with Google tools | Keynote
# Engage with the Machine Learning community | Keynote
# How Machine Learning tools at Google made AlphaFold possible | Keynote
# Machine Learning for mobile | Keynote
# Machine learning tools from Google 2021 | Keynote
# Google's Machine Learning Virtual Community Day livestream
# Powered by TensorFlow: How machine learning helps advance access to human rights information
# Powered by TensorFlow: Creating a custom, machine learning-powered drumming arm
# Self Driving Cars using Udacity Car Simulator - Made with TensorFlow.js
# Making OSS Machine Learning communities more diverse | Keynote
# Gradient ascent for your career | Breakout session
# I'm a developer, how can I become an ML developer? | Breakout session
# Why diversity matters in Machine Learning communities | Keynote
# How to get started in Machine Learning | Breakout session
# Get involved in Machine Learning
# From being the only woman in the room to empowering the next generation | Fireside chat
# Pose estimation for sport routines - Made with TensorFlow.js
# Top takeaways from Women in Machine Learning Symposium 2021
# Visualizing autoencoders - Made with TensorFlow.js
# Classifying satellite imagery - Made with TensorFlow.js
# Women in Machine Learning Symposium 2021 livestream
# Announcing Google's Machine Learning Virtual Community Day
# Accessible data science with Hal9 - Made with TensorFlow.js
# Real time motion capture for VTubers  - Made with TensorFlow.js
# Introducing the first Women in Machine Learning Symposium
# TensorFlow.js Community "Show & Tell" #6
# How to make TensorFlow models run faster on GPUs
# Efficient serving with ScaNN for retrieval (Building recommendation systems with TensorFlow)
# Best practices for ML product decisions (ML Tech Talks)
# Deep & Cross Network (Building recommendation systems with TensorFlow)
# Federated learning: Basics and application to the mobile keyboard (ML Tech Talks)
# Leveraging context features and multitask learning (Building recommendation systems with TensorFlow)
# Transfer learning and Transformer models (ML Tech Talks)
# Building a ranking model with TF Recommenders (Building recommendation systems with TensorFlow)
# Introduction to Explainable AI (ML Tech Talks)
# Intro to TensorFlow Recommenders (Building recommendation systems with TensorFlow)
# Content-based filtering & collaborative filtering (Building recommendation systems with TensorFlow)
# Generative Adversarial Networks and TF-GAN (ML Tech Talks)
# Recommendation systems overview (Building recommendation systems with TensorFlow)
# Building AI models for healthcare (ML Tech Talks)
# TFLite delegates
# 模型优化工具箱（MOT）
# 使用TF Object Detection API训练模型
# TFLite深入介绍
# 使用TFLite Model Maker和Task API快速开发机器学习app
# 使用训练好的TFLite模型以及TFLite常见使用场景
# 使用TFLite Model Maker完成看图识花app
# TFLite快速简介
# Intro to graph neural networks (ML Tech Talks)
# A friendly introduction to linear algebra for ML (ML Tech Talks)
# TensorFlow from the ground up (ML Tech Talks)
# Gesture control for in-car systems with DepthSense and React Native - Made with TensorFlow.js
# Getting started with TensorFlow Cloud
# Train TensorFlow models at cloud scale with TensorFlow Cloud | Demo
# Beyond evaluation: Improving fairness with Model Remediation | Demo
# Easily deploy TF Lite models to the web | Demo
# TensorFlow.js: Make a smart webcam in JS with a pre-trained ML model | Workshop
# Google's AI Map | Q&A
# Building trusted AI products | Workshop
# Make your app a product with the TFX team | Q&A
# Build and deploy custom object detection model with TensorFlow Lite | Workshop
# Building with TensorFlow Lite for microcontrollers | Workshop
# Machine Learning on the web with TensorFlow.js | Q&A
# What is TensorFlow Cloud?
# Hands on with Cloud AI | Workshop
# Anomaly detection with TensorFlow | Workshop
# On-device machine learning in mobile and web apps | Q&A
# Top 10 AI and ML developer updates from Google I/O 2021
# Building with the Responsible AI toolkit | Session
# TensorFlow Hub for real world impact | Session
# Cross platform computer vision made easy with Model Maker | Session
# Coral: Expanding the edge AI landscape | Session
# Optimize your TensorFlow Lite models | Session
# Does your app use ML? Make it a product with TFX | Session
# Spotting and solving everyday problems with machine learning | Session
# Machine learning for next gen web apps with TensorFlow.js | Session
# ML Kit: Turnkey APIs to use on-device ML in mobile apps | Session
# Modern Keras design patterns | Session
# Decision forests in TensorFlow | Session
# What's new in Machine Learning | Keynote
# Introduction to Tensorflow.js and Machine Learning
# Going further with text classification
# On-device product image search: Call the product search backend
# On-device object detection: Introduction
# Getting started with image classification
# Going further with Image Classification
# On-device product image search: Introduction
# Introduction to Tensorflow.js and Machine Learning
# Retraining a spam detection model to handle new edge cases
# On-device object detection: Train and deploy a custom TensorFlow Lite model
# Machine Learning for audio classification
# Getting started with text classification to detect comment spam
# On-device product image search: Build an object detector
# On-device object detection: Add a pre-trained model to your app
# Comment spam detection: Choosing a pre-made tf.js model, quantization, and word vectors explained
# Getting started with text classification
# Adding audio classification to your mobile app with a pre-trained model
# Using a TensorFlow Python MIRNet model in Node.js - Made with TensorFlow.js
# Motion based parallax with face tracking - Made with TensorFlow.js
# Tune any musical instrument with ML5 and Crepe - Made with TensorFlow.js
# Node-Red: Visual coding for ML on Raspberry Pi and beyond - Made with TensorFlow.js
# adversarial.js: Break any neural network live in your browser - Made with TensorFlow.js
# ml5.js: Creative coding with ML for all - Made with TensorFlow.js
# TensorFlow.js Community "Show & Tell" #5
# Intro to Deep Learning (ML Tech Talks)
# Xây dựng bộ phân loại hình ảnh (Machine Learning: Zero to Hero, phần 4)
# Giới thiệu về mạng nơ ron tích chập (Machine Learning: Zero to Hero, phần 3)
# Nhập môn Thị giác máy tính bằng công nghệ học máy (Machine Learning: Zero to Hero, phần 2)
# Giới thiệu về công nghệ học máy (Machine Learning: Zero to Hero, phần 1)
# Join us at TensorFlow Everywhere
# Automated Videoing Assistant - Made with TensorFlow.js
# The Mona Lisa effect - Made with TensorFlow.js
# Inside TensorFlow: Parameter server training
# Touchless interfaces for gaming and kiosks - Made with TensorFlow.js
# Customizable AR face masks - Made with TensorFlow.js
# Real-time AR Sudoku solver - Made with TensorFlow.js
# Scroobly: Motion capture for character animation - Made with TensorFlow.js
# TensorFlow.js Community "Show & Tell" #4
# ML engineering for production ML deployments with TFX (TensorFlow Fall 2020 Updates)
# Superpowers with TensorFlow.js (TF Fall 2020 Updates)
# Training and deploying ML models on edge devices (TF Fall 2020 Updates)
# Intro to On-device Machine Learning (TF Fall 2020 Updates)
# Zero to Hero with TensorFlow (TF Fall 2020 Updates)
# TensorFlow Fall 2020 updates: Keynote & what’s new since TF2.2
# Attomoto by James Seo  - Made with TensorFlow.js
# AIDEN physio assistant by Shivay Lamba - Made with TensorFlow.js
# Inside TensorFlow: TF NumPy
# Twitter sentiment analysis by Benson Ruan - Made with TensorFlow.js
# Inside TensorFlow: Building ML infra
# Touch - Less by Anders Jessen - Made with TensorFlow.js
# YogAI: TensorFlow powered yoga instructor - Made with TensorFlow.js
# WashOS and Splat with Charlie Gerard - Made with TensorFlow.js
# Real-time semantic segmentation in the browser  - Made with TensorFlow.js
# Enjoying the show - Gant Laborde - Made with TensorFlow.js
# TensorFlow.js Community "Show & Tell" #3
# Freestyle Rap "3:20" by Baba Brinkman (Quantum Summer Symposium 2020)
# Day 2 Rap Up by Baba Brinkman (Quantum Summer Symposium 2020)
# Towards a Quantum LINPACK Benchmark (Quantum Summer Symposium 2020)
# Quantum Money (Quantum Summer Symposium 2020)
# Day 2 poem by Emi Mahmoud (Quantum Summer Symposium 2020)
# Quantum Singular Value Transformation (Quantum Summer Symposium 2020)
# Quantum Algorithms for Systems of Linear Equations (Quantum Summer Symposium 2020)
# Day 2 opening keynote by Paul Dabbar (Quantum Summer Symposium 2020)
# A Multi-tool for your Quantum Algorithmic Toolbox (Quantum Summer Symposium 2020)
# Hartree-Fock on Sycamore (Quantum Summer Symposium 2020)
# Introduction to Quantum Chess (Quantum Summer Symposium 2020)
# Day 1 opening keynote by Hartmut Neven (Quantum Summer Symposium 2020)
# Certifiable Random Number Generation (Quantum Summer Symposium 2020)
# TensorFlow Quantum (Quantum Summer Symposium 2020)
# Google's Quantum Computing Service (Quantum Summer Symposium 2020)
# Quantum Circuit "Kinetics" (Quantum Summer Symposium 2020)
# Quantum Approximate Optimization (Quantum Summer Symposium 2020)
# Day 1 poem by Emi Mahmoud (Quantum Summer Symposium 2020)
# Quantum Gravity in the Lab (Quantum Summer Symposium 2020)
# Fermi-Hubbard on Sycamore (Quantum Summer Symposium 2020)
# 畳み込みニューラール・ネットワック（機械学習ゼーロからヒーローへ - 第3部）
# 画像分類器を作る（機械学習ゼーロからヒーローへ - 第4部）
# 機械学習を用いたコンピュータービジョンの基本（機械学習ゼロからヒーローへ　第二部）
# 初めての機械学習（機械学習ゼロからヒーローへ　第一部）
# Inside TensorFlow: Quantization aware training
# Powered by TensorFlow: Air Cognizer predicts air quality with machine learning
# Why TensorFlow?
# Inside TensorFlow: New TF Lite Converter
# Powered by TensorFlow: Helping Médecins Sans Frontières staff prescribe antibiotics for infections
# Training an AI to create poetry (NLP Zero to Hero - Part 6)
# Catherine Nelson & Hannes Hapke interview (TensorFlow Meets)
# Long Short-Term Memory for NLP (NLP Zero to Hero - Part 5)
# ML with Recurrent Neural Networks (NLP Zero to Hero - Part 4)
# Inside TensorFlow: TF Debugging
# Control of transmon qubits using a cryogenic CMOS integrated circuit (QuantumCasts)
# Extracting coherence information from random circuits (QuantumCasts)
# Quantum supremacy: Benchmarking the Sycamore processor (QuantumCasts)
# Estimation of statistical significance of quantum supremacy (QuantumCasts)
# Inside TensorFlow: TF-Agents
# Answering your latest TensorFlow questions! #AskTensorFlow
# Inside TensorFlow: tf.data + tf.distribute
# Accelerate models with TFLite Delegates (TF Dev Summit '20)
# ML solutions for Live Perception (TF Dev Summit '20)
# Layer-wise learning for quantum neural networks (TF Dev Summit '20)
# Distributed TensorFlow model training on Cloud AI Platform (TF Dev Summit '20)
# TF Lite Lens (TF Dev Summit '20)
# Easy on-device ML from prototype to production (TF Dev Summit '20)
# Optimize your models with TF Model Optimization Toolkit (TF Dev Summit '20)
# TensorFlow Lite for Microcontrollers (TF Dev Summit '20)
# TensorFlow Enterprise (TF Dev Summit '20)
# Fairness Indicators for TensorFlow (TF Dev Summit '20)
# TensorFlow Profiler demo (TF Dev Summit '20)
# TensorFlow Extended (TF Dev Summit '20)
# TensorFlow.js (TF Dev Summit '20)
# TensorFlow Lite: Reference app gallery (TF Dev Summit '20)
# TensorBoard (TF Dev Summit '20)
# Scaling Tensorflow data processing with tf.data (TF Dev Summit '20)
# TensorFlow Hub: Making model discovery easy (TF Dev Summit '20)
# Performance profiling in TF 2 (TF Dev Summit '20)
# Jacquard: Embedding ML seamlessly into everyday objects (TF Dev Summit '20)
# Research with TensorFlow (TF Dev Summit '20)
# TFRT: A new TensorFlow runtime (TF Dev Summit '20)
# MLIR: Accelerating TF with compilers (TF Dev Summit '20)
# Making the most of Colab (TF Dev Summit '20)
# TensorFlow.js: ML for the web and beyond (TF Dev Summit '20)
# TF 2.x on Kaggle (TF Dev Summit '20)
# Differentiable convex optimization layers (TF Dev Summit '20)
# Scaling TensorFlow 2 models to multi-worker GPUs (TF Dev Summit '20)
# TensorFlow Enterprise: Productionizing TensorFlow with Google Cloud (TF Dev Summit '20)
# TensorFlow Lite: ML for mobile and IoT devices (TF Dev Summit '20)
# Responsible AI with TensorFlow (TF Dev Summit '20)
# Collaborative ML with TensorBoard.dev (TF Dev Summit '20)
# Learning to read with TensorFlow and Keras (TF Dev Summit '20)
# TensorFlow Quantum: A software platform for hybrid quantum-classical ML (TF Dev Summit '20)
# Getting involved in the TF community (TF Dev Summit '20)
# TensorFlow and ML from the trenches: The Innovation Experience Center at JPL (TF Dev Summit '20)
# TensorFlow Dev Summit 2020 Livestream
# TFX: Production ML with TensorFlow in 2020 (TF Dev Summit '20)
# TensorFlow Dev Summit 2020 Keynote
# Training a model to recognize sentiment in text (NLP Zero to Hero - Part 3)
# Sequencing - Turning sentences into data (NLP Zero to Hero - Part 2)
# Natural Language Processing - Tokenization (NLP Zero to Hero - Part 1)
# Get ready for TensorFlow Dev Summit 2020!
# Neural Structured Learning - Part 4: Adversarial learning for image classification
# Neural Structured Learning - Part 3: Training with synthesized graphs
# Neural Structured Learning - Part 2: Training with natural graphs
# Inside TensorFlow: TF Filesystems
# Neural Structured Learning - Part 1: Framework overview
# Erstellen eines Bildklassifizierers (ML Zero to Hero, Teil 4)
# Einfuehrung in Konvolutionale Neuronale Netzwerke (ML Zero to Hero, Teil 3)
# Grundsätzliche Computer Vision mit ML (ML Zero to Hero, Teil 2)
# Einführung in Maschinelles Lernen (ML Zero to Hero, Teil 1)
# Inside TensorFlow: TF Model Optimization Toolkit (Quantization and Pruning)
# Создаём классификатор изображений (Машинное Обучение: Zero to Hero, часть 4)
# Введение в сверточные нейронные сети (Машинное Обучение Zero to Hero, часть 3)
# Основы Компьютерного Зрения с использованием Машинного Обучения (Машинное Обучение: часть 2)
# Введение в Машинное Обучение (Машинное Обучение: Zero to Hero, часть 1)
# 이미지 분류기 구축하기 (ML Zero to Hero 4부)
# 컨볼루셔널 뉴럴네트워크의 소개 (ML Zero to Hero 3부)
# 머신러닝 기반의 기본적인 컴퓨터 비전 (ML Zero to Hero 2부)
# 머신러닝의 소개 (ML Zero to Hero 1부)
# 构件一个图像分类器（机器学习从零到一第四集）
# 卷积神经网络简介（机器学习从零到一第三集）
# 机器学习中的基本计算机视觉概念（机器学习从零到一第二集）
# 机器学习简介（机器学习从零到一第一集)
# Federated learning with TensorFlow Federated (TF World '19)
# Inside TensorFlow: Eager execution runtime
# Introducción a las redes neuronales convolucionales (ML Zero to Hero, parte 3)
# Computer vision básica con ML (ML Zero to Hero, parte 2)
# Introducción a Machine Learning (ML Zero to Hero, parte 1)
# Construye un clasificador de imagen (ML Zero to Hero, parte 4)
# Kemal El Moujahid interview (TensorFlow Meets)
# What’s new in TensorFlow from TF World ‘19
# Inside TensorFlow: Graph rewriting (Macros, not functions)
# Construire un classifieur d'images (Coding TensorFlow en français)
# Introduction aux réseaux neuronaux convolutionnel (Coding TensorFlow en français)
# Vision par Ordinateur à l’aide de l’Apprentissage Automatique (Coding TensorFlow en français)
# Introduction à l'apprentissage automatique (Coding TensorFlow en français)
# Megan Kacholia interview (TensorFlow Meets)
# Inside TensorFlow: MLIR for TF developers
# TensorFlow World 2019 Highlights
# Introdução às redes neurais convolucionais (ML de Zero a 100, parte 3)
# Visão computacional básica com Machine Learning (ML de Zero a 100, parte 2)
# Introdução ao Machine Learning (ML de Zero a 100, parte 1)
# Construa um classificador de imagens (ML de Zero a 100, parte 4)
# Jeff Dean discusses the future of machine learning at TF World ‘19 (TensorFlow Meets)
# Inside TensorFlow: AutoGraph
# Day 2 Keynote (TF World '19)
# Unlocking the power of ML for your JavaScript applications with TensorFlow.js (TF World '19)
# Neural structured learning in TensorFlow (TF World '19)
# TensorFlow World 2019 | Day 2 Livestream PM
# TFX: Production ML pipelines with TensorFlow (TF World '19)
# TensorFlow model optimization: Quantization and pruning (TF World '19)
# TensorFlow Lite: Solution for running ML on-device (TF World '19)
# Great TensorFlow Research Cloud projects from around the world (TF World '19)
# TensorFlow World 2019 | Day 1 Livestream
# Getting involved in the TensorFlow community (TF World '19)
# Performant, scalable models in TensorFlow 2 with tf.data, tf.function & tf.distribute (TF World '19)
# Building models with tf.text (TF World '19)
# Swift for TensorFlow (TF World '19)
# Introduction to TensorFlow 2.0: Easier for beginners, and more powerful for experts (TF World '19)
# TensorFlow World 2019 Keynote
# Inside TensorFlow: TensorFlow Lite
# Powered by TensorFlow: Helping doctors detect respiratory diseases using machine learning
# Announcing TensorFlow 2.0 (Coding TensorFlow)
# Construa uma rede neural para executar a classificação (Coding TensorFlow em português)
# Prepare o seu conjunto de dados para machine learning (Coding TensorFlow em português)
# Build an image classifier (ML Zero to Hero - Part 4)
# Introducing convolutional neural networks (ML Zero to Hero - Part 3)
# Basic Computer Vision with ML (ML Zero to Hero - Part 2)
# Intro to Machine Learning (ML Zero to Hero - Part 1)
# Inside TensorFlow: tf.Keras (part 2)
# Inside TensorFlow: tf.Keras (Part 1)
# Inside TensorFlow: tf.distribute.Strategy
# Model Understanding and Business Reality (TensorFlow Extended)
# Answering your TF Lite questions and more! #AskTensorFlow
# Distributed Processing and Components (TensorFlow Extended)
# Why do I need metadata? (TensorFlow Extended)
# How do TFX pipelines work? (TensorFlow Extended)
# TensorFlow.js (TensorFlow Meets)
# What exactly is this TFX thing? (TensorFlow Extended)
# TF-Agents: Reinforcement Learning (TensorFlow Meets)
# TensorFlow 2.0 and Keras #AskTensorFlow
# TensorFlow Extended (TFX) and Metadata (TensorFlow Meets)
# Inside TensorFlow: Functions, not sessions
# TensorFlow 2.0: An Overview #AskTensorFlow
# Arun Subramaniyan discusses probabilistic modeling (TensorFlow Meets)
# Working with TensorFlow Datasets (TensorFlow Meets)
# Inside TensorFlow: Resources and Variants
# The Power of Swift for Machine Learning (TensorFlow Meets)
# ML & AI sandbox demos at Google I/O 2019
# Inside TensorFlow: Summaries and TensorBoard
# TensorFlow Lite for on-device ML  (TensorFlow Meets)
# TensorFlow 2.0 upgrade, Python support, & more! #AskTensorFlow
# Dance Like, an app that helps users learn how to dance using machine learning
# Introducing Google Coral: Building On-Device AI (Google I/O'19)
# A Fireside Chat with Turing Award Winner Geoffrey Hinton, Pioneer of Deep Learning (Google I/O'19)
# Cutting Edge TensorFlow: New Techniques (Google I/O'19)
# TF-Agents: A Flexible Reinforcement Learning Library for TensorFlow (Google I/O'19)
# Cloud TPU Pods: AI Supercomputing for Large Machine Learning Problems (Google I/O'19)
# Machine Learning Fairness: Lessons Learned (Google I/O'19)
# Machine Learning Zero to Hero (Google I/O'19)
# Machine Learning for Game Developers (Google I/O'19)
# Federated Learning: Machine Learning on Decentralized Data (Google I/O'19)
# Writing the Playbook for Fair & Ethical Artificial Intelligence & Machine Learning (Google I/O'19)
# Deep Learning to Solve Challenging Problems (Google I/O'19)
# Machine Learning Magic for Your JavaScript Application (Google I/O'19)
# TensorFlow Extended (TFX): Machine Learning Pipelines and Model Understanding (Google I/O'19)
# Swift for TensorFlow (Google I/O'19)
# AI for Mobile and IoT Devices: TensorFlow Lite (Google I/O'19)
# Getting Started with TensorFlow 2.0 (Google I/O'19)
# Machine Learning on Your Device: The Options (Google I/O'19)
# High-Level APIs in TensorFlow 2.0 (TensorFlow Meets)
# Using GPUs in TensorFlow, TensorBoard in notebooks, finding new datasets, & more! #AskTensorFlow
# Inside TensorFlow: tf.data - TF Input Pipeline
# How TensorFlow keeps improving (TensorFlow Meets)
# Using callbacks in training, getting started in TF 2.0, & more! #AskTensorFlow
# Swift for TensorFlow (TensorFlow Meets)
# Inside TensorFlow: Control Flow
# Discussing TensorFlow with the founder of Udacity (TensorFlow Meets)
# Building a sustainable, open source machine learning platform for everyone (TensorFlow Meets)
# Edge TPU live demo: Coral Dev Board & Microcontrollers (TF Dev Summit '19)
# PAI: Platform of A.I. in Alibaba (TF Dev Summit '19)
# TensorFlow Dev Summit 2019 Highlights #MachineLearning
# TensorFlow Federated (TFF): Machine Learning on Decentralized Data (TF Dev Summit ‘19)
# Sonnet 2.0 (TF Dev Summit ‘19)
# Mesh-TensorFlow: Model Parallelism for Supercomputers (TF Dev Summit ‘19)
# Exascale Deep Learning for Climate Analytics (TF Dev Summit ‘19)
# AI Experiments: Making AI Accessible through Play (TF Dev Summit ‘19)
# Improving Text In Tensorflow (TF Dev Summit ‘19)
# TF Lattice: Control Your ML with Monotonicity (TF Dev Summit '19)
# Building a Visual Debugging Tool for ML - TF.js in Interactive Visual Analytics (TF Dev Summit '19)
# Netease Youdao: AI Leader in Online Education in China (TF Dev Summit '19)
# TensorFlow.jl: A Julia Front End to the TensorFlow World (TF Dev Summit '19)
# Democratizing Ultrasound via ML (TF Dev Summit '19)
# Powered by TensorFlow: utilizing deep learning to better predict extreme weather
# Powered by TensorFlow: helping paleographers transcribe medieval text using machine learning
# TensorFlow Extended (TFX) Overview and Pre-training Workflow (TF Dev Summit '19)
# TensorFlow Extended (TFX) Post-training Workflow (TF Dev Summit '19)
# TensorFlow Probability: Learning with confidence (TF Dev Summit '19)
# Reinforcement Learning in TensorFlow with TF-Agents (TF Dev Summit '19)
# TensorFlow Hub: Reusable Machine Learning (TF Dev Summit '19)
# TensorFlow.js 1.0 (TF Dev Summit '19)
# In Codice Ratio: Machine Transcription in the Vatican Secret Archive (TF Dev Summit '19)
# TensorFlow Open Source Community And Collaboration  (TF Dev Summit '19)
# TensorFlow Dev Summit 2019 Livestream
# Introducing TensorFlow 2.0 and its high-level APIs (TF Dev Summit '19)
# Swift for TensorFlow: The Next-Generation Machine Learning Framework (TF Dev Summit '19)
# What's new in TensorBoard (TF Dev Summit '19)
# TensorFlow Datasets (TF Dev Summit '19)
# tf.function and Autograph (TF Dev Summit ‘19)
# TensorFlow Lite (TF Dev Summit ‘19)
# TensorFlow Dev Summit 2019 Keynote
# Powered by TensorFlow: Airbnb uses machine learning to help categorize its listing photos
# Quantum supremacy explained (QuantumCasts)
# Get started with using TensorFlow to solve for regression problems (Coding TensorFlow)
# Machine learning developers - TensorFlow Dev Summit '19 is here!
# Upgrade your existing code for TensorFlow 2.0 (Coding TensorFlow)
# Programming a quantum computer with Cirq (QuantumCasts)
# How to take advantage of GPUs and TPUs for your ML project (Coding TensorFlow)
# Construya una red neuronal para realizar la clasificación - Episodio 3
# Build a deep neural network in 4 mins with TensorFlow in Colab
# Building a quantum computer with superconducting qubits (QuantumCasts)
# Getting Started with TensorFlow in Google Colaboratory (Coding TensorFlow)
# Utilize o TensorFlow.js no seu navegador (Coding TensorFlow em português)
# Prepare su conjunto de datos para el aprendizaje automático - Episodio 2
# Get started with Google Colaboratory (Coding TensorFlow)
# TensorFlow Lite, Experimental GPU Delegate (Coding TensorFlow)
# AutoGraph: Easy control flow for graphs (TensorFlow Tip of the Week)
# Deep learning for fundamental sciences using high-performance computing (O’Reilly AI Conference)
# TensorFlow high-level APIs: Part 3 - Building and refining your models
# Tensor2Tensor (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# TensorFlow for JavaScript (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# TF Machine Learning for Programmers (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# TensorFlow Extended (TFX) & Hub (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# TensorFlow high-level APIs: Part 2 - going deep on data and features
# What is a quantum computer? (QuantumCasts)
# Distributed TensorFlow (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# TensorFlow high-level APIs: Part 1 - loading data
# Coding Tensorflow en Español - Episodio 1
# Swift for TensorFlow (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# Quickly get CSV into datasets for Keras (TensorFlow Tip of the Week)
# TensorFlow Lite (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# TensorFlow AutoGraph (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# Using TensorBoard with Keras (TensorFlow Tip of the Week)
# Cloud TPUs (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# Welcome to QuantumCasts! A new series on quantum computing
# TensorFlow Probability (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# Building AI with TensorFlow: An Overview (TensorFlow @ O’Reilly AI Conference, San Francisco '18)
# Saving and Loading Models (Coding TensorFlow)
# Solve your model’s overfitting and underfitting problems - Pt.2 (Coding TensorFlow)
# Solve your model’s overfitting and underfitting problems - Pt.1 (Coding TensorFlow)
# Designing a neural network | Text Classification Tutorial Pt. 2 (Coding TensorFlow)
# Add TensorFlow Lite to your Android App (TensorFlow Tip of the Week)
# Prepare your data for ML  | Text Classification Tutorial Pt. 1 (Coding TensorFlow)
# How to convert your ML model to TensorFlow Lite (TensorFlow Tip of the Week)
# A demo of One Hot Encoding (TensorFlow Tip of the Week)
# Affective Deep Learning Research (TensorFlow Meets)
# Use TensorFlow to classify clothing images (Coding TensorFlow)
# TensorFlow Meets with Laurence and his brain (TensorFlow Meets)
# Dyad X Machina: bringing emotion into machine learning (TensorFlow Meets)
# De-bug your TensorFlow projects with the PyCharm IDE (TensorFlow Tip of the Week)
# How to get your browser ready for TensorFlow (TensorFlow Tip of the Week)
# Build a neural network to perform classification | TensorFlow.js (Coding TensorFlow)
# The Coca-Cola Company using TensorFlow for digital marketing campaigns (TensorFlow Meets)
# TFX: an end-to-end machine learning platform for TensorFlow (TensorFlow Meets)
# Using ML to predict insulin use for Type 1 Diabetes (TensorFlow Meets)
# Prepare your dataset for machine learning (Coding TensorFlow)
# Training models faster with TensorFlow Hub (TensorFlow Meets)
# How to use TensorFlow in PyCharm (TensorFlow Tip of the Week)
# TensorFlow Hub: reusing machine learning modules (TensorFlow Meets)
# Try TensorFlow.js in your browser (Coding TensorFlow)
# NVidia TensorRT: high-performance deep learning inference accelerator (TensorFlow Meets)
# At the intersection of TensorFlow & nuclear physics (TensorFlow Meets)
# The growth of TensorFlow with added support for JS & Swift (TensorFlow Meets)
# MiniGo: TensorFlow Meets Andrew Jackson (TensorFlow Meets)
# TensorFlow - the deep learning solution for mobile platforms (TensorFlow Meets)
# How to get started with AI/ML, retraining models, & more! #AskTensorFlow
# Focus on your experiment with TensorFlow Estimators (TensorFlow Meets)
# TensorFlow and Keras in R - Josh Gordon meets with J.J. Allaire (TensorFlow Meets)
# Classification using neural networks & ML regression models #AskTensorFlow
# Distributed TensorFlow training (Google I/O '18)
# Advances in machine learning and TensorFlow (Google I/O '18)
# TensorFlow Lite for mobile developers (Google I/O '18)
# TensorFlow and deep reinforcement learning, without a PhD (Google I/O '18)
# Get started with TensorFlow's High-Level APIs in 5 mins |  Google I/O 2018
# TensorFlow in production: TF Extended, TF Hub, and TF Serving (Google I/O '18)
# TensorFlow for JavaScript (Google I/O '18)
# Get started with TensorFlow's High-Level APIs (Google I/O '18)
# TensorFlow Lite for iOS (Coding TensorFlow)
# Execute operations immediately with TensorFlow's Eager Execution (TensorFlow Meets)
# Training Models in the Cloud & the Benefits of AI Toolkits #AskTensorFlow
# Using the tf.data API to build input pipelines (TensorFlow Meets)
# TensorFlow Lite for Android (Coding TensorFlow)
# Teaching TensorFlow for Deep Learning at Stanford University (TensorFlow Meets)
# Using TensorFlow to enable research & production across many fields (TensorFlow Meets)
# TensorFlow Mobile vs. TF Lite and More! #AskTensorFlow
# Jeff Dean, Head of AI at Google discusses the impact of ML (TensorFlow Meets)
# TensorFlow Dev Summit 2018 Highlights
# Introducing TensorFlow Lite (Coding TensorFlow)
# TensorFlow Dev Summit 2018 - Livestream
# Project Magenta (TensorFlow Dev Summit 2018)
# TensorFlow Extended (TFX) (TensorFlow Dev Summit 2018)
# Real-World Robot Learning (TensorFlow Dev Summit 2018)
# Applied AI at The Coca-Cola Company (TensorFlow Dev Summit 2018)
# TensorFlow Hub (TensorFlow Dev Summit 2018)
# Swift for TensorFlow - TFiwS (TensorFlow Dev Summit 2018)
# Open Source Collaboration (TensorFlow Dev Summit 2018)
# Nucleus: TensorFlow toolkit for Genomics (TensorFlow Dev Summit 2018)
# Reconstructing Fusion Plasmas (TensorFlow Dev Summit 2018)
# Searching Over Ideas (TensorFlow Dev Summit 2018)
# TensorFlow Lite (TensorFlow Dev Summit 2018)
# Debugging TensorFlow with TensorBoard plugins (TensorFlow Dev Summit 2018)
# Distributed TensorFlow (TensorFlow Dev Summit 2018)
# The Practitioner's Guide with TF High Level APIs (TensorFlow Dev Summit 2018)
# Training Performance: A user’s guide to converge faster (TensorFlow Dev Summit 2018)
# Machine Learning in JavaScript (TensorFlow Dev Summit 2018)
# Eager Execution (TensorFlow Dev Summit 2018)
# tf.data: Fast, flexible, and easy-to-use input pipelines (TensorFlow Dev Summit 2018)
# Keynote (TensorFlow Dev Summit 2018)
# TensorFlow: an ML platform for solving impactful and challenging problems
# All About TensorFlow Code (Coding TensorFlow)
# Chatting With the TensorFlow Community (TensorFlow Meets)
# Answering Your TF Questions #AskTensorFlow
# The TensorFlow YouTube Channel is Here!
